# %%
#Libraries, Read Out Dataset

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline
dataset = pd.read_csv('Bahrain GP 2023.csv')
dataset.head(20)
# Out:
#     position           driver  driverid     constructor  constructorid  laps  \
# 0        1.0   Max Verstappen      50.0        Red Bull            9.0    57
# 1        2.0     Sergio Pérez      81.5        Red Bull            9.0    57
# 2        3.0  Fernando Alonso       4.0    Aston Martin           11.7    57
# 3        4.0     Carlos Sainz      83.2         Ferrari            6.0    57
# 4        5.0   Lewis Hamilton       1.0        Mercedes           13.1    57
# 5        6.0     Lance Stroll      84.0    Aston Martin           11.7    57
# 6        7.0   George Russell      84.7        Mercedes           13.1    57
# 7        8.0  Valtteri Bottas      77.0      Alfa Romeo           51.0    57
# 8        9.0     Pierre Gasly      84.2  Alpine F1 Team           21.4    57
# 9       10.0  Alexander Albon      23.0        Williams            3.0    57
# 10      11.0     Yuki Tsunoda      85.2      AlphaTauri           21.3    57
# 11      12.0   Logan Sargeant      85.8        Williams            3.0    56
# 12      13.0  Kevin Magnussen      76.0    Haas F1 Team           21.0    56
# 13      14.0    Nyck de Vries      21.0      AlphaTauri           21.3    56
# 14      15.0  Nico Hülkenberg      27.0    Haas F1 Team           21.0    56
# 15      16.0      Guanyu Zhou      24.0      Alfa Romeo           51.0    56
# 16      17.0     Lando Norris      84.6         McLaren            1.0    55
# 17       NaN     Esteban Ocon      83.9  Alpine F1 Team           21.4    41
# 18       NaN  Charles Leclerc      84.4         Ferrari            6.0    39
# 19       NaN    Oscar Piastri      85.7         McLaren            1.0    13
#
#            time  points  grid
# 0   1:33:56.736      25     1
# 1        11.987      18     2
# 2        38.637      15     5
# 3        48.052      12     4
# 4        50.977      10     7
# 5        54.502       8     8
# 6        55.873       6     6
# 7     +1:12.647       4    12
# 8     +1:13.753       2    20
# 9     +1:29.774       1    15
# 10    +1:30.870       0    14
# 11       +1 Lap       0    16
# 12       +1 Lap       0    17
# 13       +1 Lap       0    19
# 14       +1 Lap       0    10
# 15       +1 Lap       0    13
# 16      +2 Laps       0    11
# 17   Mechanical       0     9
# 18       Engine       0     3
# 19   Electrical       0    18

# %%
# X = Drivers ID, y = Final Position, Z = Constructors ID, H = Grid

X = dataset.iloc[:-3, 2:-6].values
y = dataset.iloc[:-3, :-8].values
Z = dataset.iloc[:-3, 4:-4].values
H = dataset.iloc[:-3, 8:].values

# %%
# Machine Learning Regression Grid vs Final Position

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(H, y)
# Out:
# LinearRegression()

# %%
# Bahrain GP 23 Driver Position

plt.figure(figsize=(15,10))
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.scatter(X, y, color = 'blue')
plt.title('Bahrain GP 23 Driver Positions')
plt.xlabel('Driver ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Bahrain GP 23 Constructor Position

plt.figure(figsize=(15,10))
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.scatter(Z, y, color = 'blue')
plt.title('Bahrain GP 23 Constructor Positions')
plt.xlabel('Constructor ID')
plt.ylabel('Position')
# Out:
# Text(0, 0.5, 'Position')

# %%
# Bahrain GP 23 Driver Points

f, ax = plt.subplots(figsize=(15,10))
sns.barplot(x='points', y='driver', data=dataset)
plt.title('Bahrain GP 23 Driver Points')
plt.xlabel('GP Points')
plt.ylabel('Drivers')
# Out:
# Text(0, 0.5, 'Drivers')

# %%
# Bahrain GP 23 Constructor Points

f, ax = plt.subplots(figsize=(15,10))
sns.barplot(x='points', y='constructor', data=dataset)
plt.title('Bahrain GP 23 Constructor Points')
plt.xlabel('GP Points')
plt.ylabel('Constructors')
# Out:
# Text(0, 0.5, 'Constructors')

# %%
# Bahrain GP 23 Grid VS Finish Points

plt.figure(figsize=(15,10))
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.scatter(H, y, color = 'red')
plt.plot(H, regressor.predict(H), color = 'blue')
plt.title('Grid VS Finish')
plt.xlabel('Start Position')
plt.ylabel('Finish Position')
# Out:
# Text(0, 0.5, 'Finish Position')
